# %% [markdown]
# # E-Commerce Apriori Implementation -- Joseph Kim

# %%
import pandas as pd
import numpy as np

from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules

import kaggle

# %%
# download through kaggle api
kaggle.api.dataset_download_files('lissetteg/ecommerce-dataset', path='kaggle', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/lissetteg/ecommerce-dataset
# c:\Users\josep\miniconda3\lib\site-packages\kaggle\api_client.py:165: DeprecationWarning: HTTPResponse.getheaders() is deprecated and will be removed in urllib3 v2.1.0. Instead access HTTPResponse.headers directly.
#   response_data.getheaders())

# %%
# csv from kaggle is called 'data-2'
df = pd.read_csv('kaggle/data-2.csv')

# %% [markdown]
# Data Processing for mlxtend

# %%
df['Description'] = df['Description'].str.strip()
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df = df[df['Quantity'] > 0] # remove all quantities that are below 0, as this is not possible

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 9  12/1/2010 8:34       1.69     13047.0  United Kingdom

# %%
# based on the data, convert into a pivot table from pandas -- this is necessary for apriori to work / manually see association rules
basket = pd.pivot_table(data=df, index='InvoiceNo', columns='Description', values='Quantity', aggfunc='sum', fill_value = 0)
basket.head()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                           0                        0
# 536366                           0                        0
# 536367                           0                        0
# 536368                           0                        0
# 536369                           0                        0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                            0                           0
# 536366                            0                           0
# 536367                            0                           0
# 536368                            0                           0
# 536369                            0                           0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                               0                          0
# 536366                               0                          0
# 536367                               0                          0
# 536368                               0                          0
# 536369                               0                          0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                  0                                 0
# 536366                                  0                                 0
# 536367                                  0                                 0
# 536368                                  0                                 0
# 536369                                  0                                 0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                     0                              0
# 536366                                     0                              0
# 536367                                     0                              0
# 536368                                     0                              0
# 536369                                     0                              0
#
# Description  ...  returned  taig adjust  test  \
# InvoiceNo    ...
# 536365       ...         0            0     0
# 536366       ...         0            0     0
# 536367       ...         0            0     0
# 536368       ...         0            0     0
# 536369       ...         0            0     0
#
# Description  to push order througha s stock was  website fixed  \
# InvoiceNo
# 536365                                        0              0
# 536366                                        0              0
# 536367                                        0              0
# 536368                                        0              0
# 536369                                        0              0
#
# Description  wrongly coded 20713  wrongly coded 23343  wrongly marked  \
# InvoiceNo
# 536365                         0                    0               0
# 536366                         0                    0               0
# 536367                         0                    0               0
# 536368                         0                    0               0
# 536369                         0                    0               0
#
# Description  wrongly marked 23343  wrongly sold (22719) barcode
# InvoiceNo
# 536365                          0                             0
# 536366                          0                             0
# 536367                          0                             0
# 536368                          0                             0
# 536369                          0                             0
#
# [5 rows x 4065 columns]

# %%
def convert_into_binary(x): # for apriori, we don't need exact quantity as long as it is over 1, so convert into binary
    if x > 0:
        return 1
    else:
        return 0

# %%
basket = basket.map(convert_into_binary)

# %%
# remove POSTAGE here because that is misleading and is not a product
basket.drop(columns = ['POSTAGE'], inplace = True)

# %% [markdown]
# Apriori Implementation -- Min Support and Association Rules

# %%
# identify frequent itemsets (support >= 0.03)
# 0.03 min support is chosen so that the frequent itemsets contain only products with 0.03 * 4065 frequency or more items present in 'basket'
frequent_itemsets = apriori(basket, min_support = 0.03, use_colnames = True)
frequent_itemsets
# Out:
# c:\Users\josep\miniconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#       support                                           itemsets
# 0    0.047427                           (6 RIBBONS RUSTIC CHARM)
# 1    0.030691                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 2    0.041120                      (60 TEATIME FAIRY CAKE CASES)
# 3    0.030542                   (72 SWEETHEART FAIRY CAKE CASES)
# 4    0.048669                       (ALARM CLOCK BAKELIKE GREEN)
# ..        ...                                                ...
# 130  0.040971  (JUMBO BAG PINK POLKADOT, JUMBO BAG RED RETROS...
# 131  0.033770  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 132  0.035956  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI)
# 133  0.031834  (LUNCH BAG RED RETROSPOT, LUNCH BAG  BLACK SKU...
# 134  0.030095  (LUNCH BAG RED RETROSPOT, LUNCH BAG PINK POLKA...
#
# [135 rows x 2 columns]

# %%
association = association_rules(frequent_itemsets, metric = "lift", min_threshold = 1, num_itemsets = len(basket))
association.head() # 15 common itemsets found
# Out:
#                          antecedents                        consequents  \
# 0         (ALARM CLOCK BAKELIKE RED)       (ALARM CLOCK BAKELIKE GREEN)
# 1       (ALARM CLOCK BAKELIKE GREEN)         (ALARM CLOCK BAKELIKE RED)
# 2  (GREEN REGENCY TEACUP AND SAUCER)   (PINK REGENCY TEACUP AND SAUCER)
# 3   (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 4  (ROSES REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.052195            0.048669  0.031784    0.608944  12.511932
# 1            0.048669            0.052195  0.031784    0.653061  12.511932
# 2            0.050407            0.038041  0.031436    0.623645  16.393893
# 3            0.038041            0.050407  0.031436    0.826371  16.393893
# 4            0.052940            0.050407  0.038141    0.720450  14.292598
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.029244    2.432722       0.970744  0.460101   0.588938
# 1               1.0  0.029244    2.731908       0.967146  0.460101   0.633956
# 2               1.0  0.029519    2.555990       0.988847  0.551394   0.608762
# 3               1.0  0.029519    5.469083       0.976135  0.551394   0.817154
# 4               1.0  0.035472    3.396865       0.982022  0.584920   0.705611
#
#    kulczynski
# 0    0.631003
# 1    0.631003
# 2    0.725008
# 3    0.725008
# 4    0.738550

# %% [markdown]
# Association Analysis: Generating All Possible Rules

# %%
association[ (association['lift'] >= 4) & (association['confidence'] >= 0.5) ]
# Out:
#                             antecedents                        consequents  \
# 0            (ALARM CLOCK BAKELIKE RED)       (ALARM CLOCK BAKELIKE GREEN)
# 1          (ALARM CLOCK BAKELIKE GREEN)         (ALARM CLOCK BAKELIKE RED)
# 2     (GREEN REGENCY TEACUP AND SAUCER)   (PINK REGENCY TEACUP AND SAUCER)
# 3      (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 4     (ROSES REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 5     (GREEN REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER)
# 6             (JUMBO BAG PINK POLKADOT)          (JUMBO BAG RED RETROSPOT)
# 8   (JUMBO SHOPPER VINTAGE RED PAISLEY)          (JUMBO BAG RED RETROSPOT)
# 11             (JUMBO STORAGE BAG SUKI)          (JUMBO BAG RED RETROSPOT)
# 13            (LUNCH BAG  BLACK SKULL.)          (LUNCH BAG RED RETROSPOT)
# 15            (LUNCH BAG PINK POLKADOT)          (LUNCH BAG RED RETROSPOT)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.052195            0.048669  0.031784    0.608944  12.511932
# 1             0.048669            0.052195  0.031784    0.653061  12.511932
# 2             0.050407            0.038041  0.031436    0.623645  16.393893
# 3             0.038041            0.050407  0.031436    0.826371  16.393893
# 4             0.052940            0.050407  0.038141    0.720450  14.292598
# 5             0.050407            0.052940  0.038141    0.756650  14.292598
# 6             0.060489            0.103894  0.040971    0.677340   6.519558
# 8             0.058353            0.103894  0.033770    0.578723   5.570351
# 11            0.058800            0.103894  0.035956    0.611486   5.885704
# 13            0.063220            0.077672  0.031834    0.503535   6.482852
# 15            0.054132            0.077672  0.030095    0.555963   7.157850
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                1.0  0.029244    2.432722       0.970744  0.460101
# 1                1.0  0.029244    2.731908       0.967146  0.460101
# 2                1.0  0.029519    2.555990       0.988847  0.551394
# 3                1.0  0.029519    5.469083       0.976135  0.551394
# 4                1.0  0.035472    3.396865       0.982022  0.584920
# 5                1.0  0.035472    3.891765       0.979403  0.584920
# 6                1.0  0.034687    2.777246       0.901123  0.331992
# 8                1.0  0.027708    2.127121       0.871323  0.262853
# 11               1.0  0.029847    2.306500       0.881956  0.283699
# 13               1.0  0.026923    1.857791       0.902823  0.291894
# 15               1.0  0.025891    2.077144       0.909528  0.295898
#
#     certainty  kulczynski
# 0    0.588938    0.631003
# 1    0.633956    0.631003
# 2    0.608762    0.725008
# 3    0.817154    0.725008
# 4    0.705611    0.738550
# 5    0.743047    0.738550
# 6    0.639931    0.535850
# 8    0.529881    0.451886
# 11   0.566443    0.478783
# 13   0.461726    0.456691
# 15   0.518570    0.471716
